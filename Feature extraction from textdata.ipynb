# %% [markdown]
# the mapping from the textual data to real valued vectors is called feature extraction

# %%
#convert the textual data to feature vectors
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data)
print(x)

# %%
#the abover code will transform all the textual  data to numerical data
#now we can give our machine learning model a numerical data to predict whether this news is fake
