# %%
pip install kaggle

# %% [markdown]
# # importing the dependencies

# %%
import os
import json
import pandas as pd

from zipfile import ZipFile
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import seq
# Out:
#   File "<ipython-input-3-77337686db8b>", line 3
#     from zipfile impo
#                  ^
# SyntaxError: invalid syntax
