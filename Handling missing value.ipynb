# %% [markdown]
# # methods to handle missing values
# imputation
#
#
# dropping

# %%
#importing libraries#

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the dataset to pandas dataframe

# %%
dataset=pd.read_csv('/content/Placement_Dataset.csv')
dataset.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# that last NaN is the missing value

# %%
dataset.shape
# Out:
# (215, 15)

# %% [markdown]
# # lets see the missing value using isnull() function

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# in 215 row there are67 are missing values

# %% [markdown]
# # central tendencies

# %% [markdown]
# ## mean
# ## medium
# ## mode

# %%
#analyse the distribution of the data in the salary
fig, ax =plt.subplots(figsize=(10,5))
sns.distplot(dataset['salary'])
# Out:
# <ipython-input-11-23e9fbf5da86>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['salary'])
# <Axes: xlabel='salary', ylabel='Density'>

# %% [markdown]
# #you can use mean or medium as a replacement ofthe missing values

# %%
#replace the missing values with median values

# %%
dataset['salary'].fillna(dataset['salary'].median(),inplace= True)
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # filling missing calues with mean values

# %%
#dataset['salary'].fillna(dataset['salary'].mean(),inplace=True

# %% [markdown]
# ## filling missing calues with mode values

# %%
#dataset['salary'].fillna(dataset['salary'].mode(),inplace=True

# %% [markdown]
# so this is imputation this is how you can impute the missing values with the statistical central tendencies like mean median and mode

# %% [markdown]
# # DROPPING METHOD

# %% [markdown]
# ## the dropping method is not always recommented it may causes missing data it can be used only if its a large type of data dont use it always use imputation method to fill missing values

# %%
salary_dataset=pd.read_csv('/content/Placement_Dataset.csv')
salary_dataset.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
salary_dataset.shape
# Out:
# (215, 15)

# %%
salary_dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#lets drop the missing values

# %%
salary_dataset.dropna(inplace=True)

# %%
salary_dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
salary_dataset.shape
# Out:
# (148, 15)
